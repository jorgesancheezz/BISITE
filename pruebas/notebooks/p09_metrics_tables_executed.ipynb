# %% [markdown]
# # Tablas de métricas — P09 vs Article
#
# Las tablas están incrustadas a continuación como salidas HTML para que se vean sin ejecutar celdas.

# %%
markdown
markdown
## P09 Processed vs Article — Summary (tabla)
| pair | mmd2 | mmd_sigma | energy | ks_stat | ks_p | wasserstein | mean_diff_proj | psd_l2 | discriminator_auc | CFID | DTW |
|---|---:|---:|---:|---:|---:|---:|---:|---:|---:|---:|---:|
| P09_processed_AF_vs_Article_AF | 0.7388 | 23.8780 | 0.8491 | 0.9961 | 0.0 | 26.7473 | 26.6507 | 25.2387 | 0.9990 | 158.1076 | 0.1201 |
| P09_processed_NSR_vs_Article_NSR | 0.7704 | 23.5914 | 0.8624 | 0.9951 | 0.0 | 3.8403 | 3.6265 | 0.0062 | 1.0 | 46.1911 | 0.1436 |
markdown
markdown
## P09 / P10 vs Article — Summary (tabla)
| pair | mmd2 | mmd_sigma | energy | ks_stat | ks_p | wasserstein | mean_diff_proj | psd_l2 | discriminator_auc | CFID | DTW |
|---|---:|---:|---:|---:|---:|---:|---:|---:|---:|---:|---:|
| P09AF_vs_ArticleAF | 0.7387 | 23.8796 | 0.8491 | 0.9961 | 0.0 | 26.7473 | 26.6507 | 25.2387 | 0.9990 | 158.1078 | 0.1201 |
| P10AF_vs_ArticleAF | 0.2469 | 59.1167 | 0.7133 | 0.6963 | 5.73e-238 | 5.7112 | 3.3965 | 0.6676 | 1.0 | 37.8176 | 0.2918 |
| P09NSR_vs_ArticleNSR | 0.7700 | 23.6011 | 0.8624 | 0.9951 | 0.0 | 3.8403 | 3.6265 | 0.0062 | 1.0 | 46.1968 | 0.1436 |
| P10NSR_vs_ArticleNSR | 0.5343 | 27.6342 | 0.7611 | 0.9434 | 0.0 | 3.8724 | 3.6550 | 0.0761 | 1.0 | 11.3995 | 0.1324 |
# Tabla: P09 Processed vs Article (incrustada)

# %%
# Tabla: P09 / P10 vs Article (incrustada)
